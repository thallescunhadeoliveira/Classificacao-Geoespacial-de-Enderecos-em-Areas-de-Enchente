# %% [markdown]
# # Consulta de Endereço de Supermercados de Porto Alegre em áreas afetadas pelas enchentes

# %% [markdown]
# ### O objetivo é conseguir as coordenadas geográficas dos registros de supermercados e levantar a lista de supermercados impactados na região para fins didáticos

# %%
# Importando bibliotecas

import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderQuotaExceeded, GeocoderUnavailable
from geopy.extra.rate_limiter import RateLimiter
from pykml import parser
from shapely.geometry import Point, Polygon
from shapely.ops import unary_union
import time

# %% [markdown]
# ## Pegando coordenadas (latitude, longitude) a partir de um Endereço

# %% [markdown]
# ### Dados retirados desse site para fins didáticos https://www.tiendeo.com.br/Lojas/porto-alegre/supermercados#google_vignette

# %%
# Importando arquivo XLSX com a lista de endereços
tabela_supermercados = pd.read_excel("Supermercados Porto Alegre.xlsx")

# %%
tabela_supermercados.head()
# Out:
#                                      lista_enderecos  latitude  longitude  \
# 0  Avenida Plínio Brasil Milano 2343. - Porto Ale...       NaN        NaN
# 1         Av. A. J. Renner, 1603. - Porto Alegre, RS       NaN        NaN
# 2  Avenida Diario de Noticias, 500. 90810-080 - P...       NaN        NaN
# 3  Avenida Diario de Noticias, 500 Cristal Bairro...       NaN        NaN
# 4  Av Aureliano Figueredo Pinto, 789 Cidade Baixa...       NaN        NaN
#
#    afetado
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
# Definindo configurações do geolocator para acessar API de coordenadas
geolocator = Nominatim(user_agent="COLOQUE AQUI UM EMAIL VÁLIDO", timeout = 10)

# %%
# Função para obter coordenadas através do endereço
def get_coordinates(address, attempt=1, max_attempts=3):
    try:
        # Buscando coordenadas pela API do GeoPY
        location = geolocator.geocode(address)
        return (location.latitude, location.longitude) if location else (None, None)
    except (GeocoderTimedOut, GeocoderQuotaExceeded, GeocoderUnavailable) as e:
        if attempt < max_attempts:
            time.sleep(2 ** attempt)  # Backoff exponencial
            return get_coordinates(address, attempt + 1, max_attempts)
        else:
            print(f"Geocoding falhou após {max_attempts} tentativas: {e}")
            return (None, None)
    except Exception as e:
        print(f"Erro ao geocodificar {address}: {e}")
        return (None, None)

# %%
# Iterar sobre cada registro da lista para buscar e registrar coordenadas

i = len(tabela_supermercados)

for index, row in tabela_supermercados.iterrows():
    # Passe o endereço da forma como estiver nos seus dados
    # Exemplo caso tenha cada item em uma coluna: 
    # address_str = f"{row['street']}, {row['number']}, {row['neighborhood']}, {row['city']}, {row['state']}, Brazil" 
    address_str = row['lista_enderecos']
    lat, lon = get_coordinates(address_str)
    # Insere os registros na tabela
    tabela_supermercados.at[index, 'latitude'] = lat
    tabela_supermercados.at[index, 'longitude'] = lon
    
    print(i)
    # Decresce o contador de iterações
    i -= 1
    print(f"Endereço: {address_str}\nLatitude: {lat}, Longitude: {lon}\n")

    time.sleep(1)  # Para evitar excesso de solicitações à API
# Out:
# 112
# Endereço: Avenida Plínio Brasil Milano 2343. - Porto Alegre, RS
# Latitude: -30.0132295, Longitude: -51.17090174375667
#
# 111
# Endereço: Av. A. J. Renner, 1603. - Porto Alegre, RS
# Latitude: -29.9829553, Longitude: -51.1921047
#
# 110
# Endereço: Avenida Diario de Noticias, 500. 90810-080 - Porto Alegre, RS
# Latitude: -30.0832343, Longitude: -51.2446005
#
# 109
# Endereço: Avenida Diario de Noticias, 500 Cristal Bairro. 90810-080 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 108
# Endereço: Av Aureliano Figueredo Pinto, 789 Cidade Baixa Bairro. 90050-191 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 107
# Endereço: Rua Fernando Machado, 860 – Centro. 90010-320 - Porto Alegre, RS
# Latitude: -30.0345365, Longitude: -51.2290198
#
# 106
# Endereço: Rua Marechal Floriano Peixoto, 333 – Centro. 90020-061 - Porto Alegre, RS
# Latitude: -30.03185895, Longitude: -51.227178004983216
#
# 105
# Endereço: Rua da Repúlblica, 500. - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 104
# Endereço: Av Aureliano Figueredo Pinto, 789 Cidade Baixa Bairro. 90050-191 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 103
# Endereço: av. praia de belas, 1181, praia de belas, porto alegre – rs. - Porto Alegre, RS
# Latitude: -30.0496165, Longitude: -51.22873253468235
#
# 102
# Endereço: Av Praia de Belas, 1181 - Praia de Belas - Bairro: - CEP: 90110-001 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 101
# Endereço: Rua Jacinto Osório, 126. - Porto Alegre, RS
# Latitude: -30.04083705, Longitude: -51.211690046752594
#
# 100
# Endereço: Avenida São Pedro, Nº 512 São Geraldo. 90230-002 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 99
# Endereço: R. Quintino Bocaiúva, 1447. 90440-051 - Porto Alegre, RS
# Latitude: -30.0262973, Longitude: -51.1976196
#
# 98
# Endereço: Av. Cristovao Colombo, Nº 1980 Floresta. 90560-002 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 97
# Endereço: R Quintino Bocaiuva, 433. 90440-051 - Porto Alegre, RS
# Latitude: -30.0218077, Longitude: -51.19861725219362
#
# 96
# Endereço: Rua Eudoro Berlink, 37 - Auxiliadora. 90450-030 - Porto Alegre, RS
# Latitude: -30.0242041, Longitude: -51.190345
#
# 95
# Endereço: Rua Coronel Bordini 300. 90440-002 - Porto Alegre, RS
# Latitude: -30.0247897, Longitude: -51.1965945
#
# 94
# Endereço: Av. Berlim, 400. 90550-070 - Porto Alegre, RS
# Latitude: -30.0150289, Longitude: -51.1949831
#
# 93
# Endereço: Rua da Repúlblica, 500. - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 92
# Endereço: Av Aureliano Figueredo Pinto, 789 Cidade Baixa Bairro. 90050-191 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 91
# Endereço: av. praia de belas, 1181, praia de belas, porto alegre – rs. - Porto Alegre, RS
# Latitude: -30.0496165, Longitude: -51.22873253468235
#
# 90
# Endereço: Av Praia de Belas, 1181 - Praia de Belas - Bairro: - CEP: 90110-001 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 89
# Endereço: Rua Jacinto Osório, 126. - Porto Alegre, RS
# Latitude: -30.04083705, Longitude: -51.211690046752594
#
# 88
# Endereço: Avenida São Pedro, Nº 512 São Geraldo. 90230-002 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 87
# Endereço: R. Quintino Bocaiúva, 1447. 90440-051 - Porto Alegre, RS
# Latitude: -30.0262973, Longitude: -51.1976196
#
# 86
# Endereço: Av. Cristovao Colombo, Nº 1980 Floresta. 90560-002 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 85
# Endereço: R Quintino Bocaiuva, 433. 90440-051 - Porto Alegre, RS
# Latitude: -30.0218077, Longitude: -51.19861725219362
#
# 84
# Endereço: Rua Eudoro Berlink, 37 - Auxiliadora. 90450-030 - Porto Alegre, RS
# Latitude: -30.0242041, Longitude: -51.190345
#
# 83
# Endereço: Rua Coronel Bordini 300. 90440-002 - Porto Alegre, RS
# Latitude: -30.0247897, Longitude: -51.1965945
#
# 82
# Endereço: Av. Berlim, 400. 90550-070 - Porto Alegre, RS
# Latitude: -30.0150289, Longitude: -51.1949831
#
# 81
# Endereço: Av. Benjamin Constant, 1695. 90550-005 - Porto Alegre, RS
# Latitude: -30.015991800000002, Longitude: -51.196841817580335
#
# 80
# Endereço: Av. São Pedro, 1163. - Porto Alegre, RS
# Latitude: -30.0122295, Longitude: -51.1977534
#
# 79
# Endereço: Rua Eudoro Berlink, 1083. - Porto Alegre, RS
# Latitude: -30.0242041, Longitude: -51.190345
#
# 78
# Endereço: Av. Protásio Alves, 2989, Loja 103. 90410-003 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 77
# Endereço: Av.Cruzeiro do Sul, 1824. - Porto Alegre, RS
# Latitude: -30.0848494, Longitude: -51.2309216
#
# 76
# Endereço: Av. Protásio Alves, 3814 - Três Figueiras. - Porto Alegre, RS
# Latitude: -30.03854395, Longitude: -51.17275431896727
#
# 75
# Endereço: Avenida Diario de Noticias, 500 Cristal Bairro. 90810-080 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 74
# Endereço: Avenida Diario de Noticias, 500 - Cristal - Bairro: - CEP: 90810-080 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 73
# Endereço: Av. Protásio Alves, 4194. 91310-000 - Porto Alegre, RS
# Latitude: -30.0407876, Longitude: -51.1588511
#
# 72
# Endereço: av. diário de notícias, 300, cristal, porto alegre – rs. - Porto Alegre, RS
# Latitude: -30.0852986, Longitude: -51.2463509
#
# 71
# Endereço: Avenida Plínio Brasil Milano 2343. - Porto Alegre, RS
# Latitude: -30.0132295, Longitude: -51.17090174375667
#
# 70
# Endereço: Avenida Diario de Noticias, 500. 90810-080 - Porto Alegre, RS
# Latitude: -30.0832343, Longitude: -51.2446005
#
# 69
# Endereço: Avenida Diario de Noticias, 500. 90810-080 - Porto Alegre, RS
# Latitude: -30.0832343, Longitude: -51.2446005
#
# 68
# Endereço: Av Ipiranga, 6681. 90610-001 - Porto Alegre, RS
# Latitude: -30.0583918, Longitude: -51.176052622657494
#
# 67
# Endereço: Av Severo Dullius, 90.010. 90200-310 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 66
# Endereço: Av. João Wallig, 1800. 91340-001 - Porto Alegre, RS
# Latitude: -30.0267982, Longitude: -51.1621428
#
# 65
# Endereço: Av. A. J. Renner, 1603. - Porto Alegre, RS
# Latitude: -29.9829553, Longitude: -51.1921047
#
# 64
# Endereço: Av. do Forte, 1396. 91370 - Porto Alegre, RS
# Latitude: -30.0104286, Longitude: -51.1533301
#
# 63
# Endereço: Rua Jaime Vignoli, 850. 90200-230 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 62
# Endereço: Anexo A, Avenida Sertório, 6600 - Sarandi. 91110580 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 61
# Endereço: Avenida Sertorio, 6600 - Sarandi - Bairro: - CEP: 91110-581 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 60
# Endereço: Avenida Sertorio, 6600 Sarandi Bairro. 91110-581 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 59
# Endereço: AV. Manoel Elias, 901, Jardim Leopoldina. 91240-260 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 58
# Endereço: Avenida Estrada Martim Félix Berta 597. 91250-200 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 57
# Endereço: Avenida Assis Brasil, 11150 - Sarandi . 91010-004 - Porto Alegre, RS
# Latitude: -29.973076, Longitude: -51.116335493318076
#
# 56
# Endereço: Avenida Economista Nilo Wulff, 970 Restinga. 91790-000 - Porto Alegre, RS
# Latitude: -30.1503719, Longitude: -51.1455592
#
# 55
# Endereço: Av. Bento Gonçalves, 68. - Porto Alegre, RS
# Latitude: -30.0556805, Longitude: -51.1985195
#
# 54
# Endereço: Av. Túlio de Rose, 80. 91320-110 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 53
# Endereço: Rua Anita Garibaldi, 536 - Mont'Serrat. 90450-000 - Porto Alegre, RS
# Latitude: -30.02669545, Longitude: -51.19032982017667
#
# 52
# Endereço: Rua Cel. Bordini, 530 – Auxiliadora. 90440-002 - Porto Alegre, RS
# Latitude: -30.0221089, Longitude: -51.1965977
#
# 51
# Endereço: Av. Assis Brasil, 4320 - São Sebastião. 91110-001 - Porto Alegre, RS
# Latitude: -30.0086757, Longitude: -51.1443961
#
# 50
# Endereço: Av. Cavalhada, 3621 – Cavalhada. 91740-001 - Porto Alegre, RS
# Latitude: -30.10847915, Longitude: -51.22865403120055
#
# 49
# Endereço: Av. Sertório, 8000 – Sarandi. 91130-720 - Porto Alegre, RS
# Latitude: -29.9993666, Longitude: -51.1313698
#
# 48
# Endereço: RUA ALBION, 111 - PARTENON, 111. 91530-010 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 47
# Endereço: Rua Fernandes Vieira, 401 - Bom Fim. 90035-090 - Porto Alegre, RS
# Latitude: -30.0327415, Longitude: -51.2111473
#
# 46
# Endereço: Av. Juca Batista, 925 – Ipanema. 91770-001 - Porto Alegre, RS
# Latitude: -30.1445819, Longitude: -51.2141015
#
# 45
# Endereço: Av Jose de Alencar, 998 - Menino Deus - Bairro: - CEP: 90880-480 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 44
# Endereço: Av Teresópolis, 2893 - Teresópolis - Bairro: - CEP: 90870-001 - Porto Alegre, RS
# Latitude: None, Longitude: None
# 43
# Endereço: Rua Múcio Teixeira, 680 - Menino Deus. 90150-090 - Porto Alegre, RS
# Latitude: -30.0512052, Longitude: -51.22376797776364
#
# 42
# Endereço: Rua Otto Niemeyer, 601 – Tristeza. 91910-001 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 41
# Endereço: R Vicente da Fontoura, 1135 - Santana - Bairro: - CEP: 90640-001 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 40
# Endereço: R Gomes de Freitas, 73 - Jardim Itu - Bairro: - CEP: 91380-000 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 39
# Endereço: R Doutor Romaguera da Cunha Correa, 60 - Bairro: - CEP: 91240-070 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 38
# Endereço: Av. Cristóvão Colombo, 545 - Prédio 6 Shopping Total. 90560-003 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 37
# Endereço: Av. Plínio Brasil Milano, 1000 – Higienópolis. 90520-002 - Porto Alegre, RS
# Latitude: -30.0202516, Longitude: -51.1812104
#
# 36
# Endereço: Rua Lima e Silva, 606 - Cidade Baixa. 90050-102 - Porto Alegre, RS
# Latitude: -30.0382877, Longitude: -51.2208916
#
# 35
# Endereço: Av. Protásio Alves, 2700 - Petrópolis. 90410-006 - Porto Alegre, RS
# Latitude: -30.0421395, Longitude: -51.1792219
#
# 34
# Endereço: Avenida Sertório - Loja 01, 6767. 91110-581 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 33
# Endereço: Av. Cristovão Colombo, 1271 – Floresta. 90560-002 - Porto Alegre, RS
# Latitude: -30.02103055, Longitude: -51.20697330470679
#
# 32
# Endereço: Avenida Assis Brasil, 2611. 91010-002 - Porto Alegre, RS
# Latitude: -30.0119437, Longitude: -51.1611213
#
# 31
# Endereço: Av. Ipiranga, 5200. 90160-001 - Porto Alegre, RS
# Latitude: -30.0551778, Longitude: -51.186631
#
# 30
# Endereço: Rua Edmundo Bastian, 791. - Porto Alegre, RS
# Latitude: -30.008495, Longitude: -51.1617768
#
# 29
# Endereço: Rua Bonifácio Nunez, 138. - Porto Alegre, RS
# Latitude: -29.9784964, Longitude: -51.1893089
#
# 28
# Endereço: Rua Bento Manoel Ribeiro, 179. - Porto Alegre, RS
# Latitude: -30.0191643, Longitude: -51.1280571
#
# 27
# Endereço: Estrada João De Oliveira Remião, 8640. - Porto Alegre, RS
# Latitude: -30.1347994, Longitude: -51.095117
#
# 26
# Endereço: Av. Juca Batista, 4255 - Hípica. 91770-001 - Porto Alegre, RS
# Latitude: -30.1590733, Longitude: -51.1897308
#
# 25
# Endereço: Av. Assis Brasil, 164. 91010-001 - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 24
# Endereço: Av. Grécia, 1500. 91010-004 - Porto Alegre, RS
# Latitude: -30.0129815, Longitude: -51.1606912
#
# 23
# Endereço: Rua Cabral, 600 - Rio Branco. 90420-100 - Porto Alegre, RS
# Latitude: -30.0339191, Longitude: -51.2023107
#
# 22
# Endereço: Av. Juca Batista, 2051. - Porto Alegre, RS
# Latitude: -30.1365877, Longitude: -51.2219471
#
# 21
# Endereço: Av. Martim Félix Berta, 385. - Porto Alegre, RS
# Latitude: -30.0162339, Longitude: -51.1069232
#
# 20
# Endereço: Av. Cavalhada, 2985. - Porto Alegre, RS
# Latitude: -30.1025756, Longitude: -51.2311271
#
# 19
# Endereço: Rua dos Andradas, 933 - Centro. 90020-005 - Porto Alegre, RS
# Latitude: -30.030835, Longitude: -51.2321847
#
# 18
# Endereço: R.Ezequiel A. Oliveira, 137. - Porto Alegre, RS
# Latitude: -30.1004997, Longitude: -51.1352741
#
# 17
# Endereço: R. Silvio S. Soares, 2429. - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 16
# Endereço: Av. Juca Batista, 1030. - Porto Alegre, RS
# Latitude: -30.1365877, Longitude: -51.2219471
#
# 15
# Endereço: Estrada da Serraria, 1557. - Porto Alegre, RS
# Latitude: -30.143993, Longitude: -51.216124
#
# 14
# Endereço: Estrada João de Oliveira Remião, 7727. - Porto Alegre, RS
# Latitude: -30.1289698, Longitude: -51.0985768
#
# 13
# Endereço: Av. Do Forte, 1679. - Porto Alegre, RS
# Latitude: -30.0256519, Longitude: -51.1512824
#
# 12
# Endereço: Av. Campos Velho, 834. - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 11
# Endereço: Av. Herval,41. - Porto Alegre, RS
# Latitude: -30.0936058, Longitude: -51.1770172
#
# 10
# Endereço: Av. Icaraí, 440. - Porto Alegre, RS
# Latitude: -30.0867437, Longitude: -51.2408665
#
# 9
# Endereço: R. Beco do Paladino, 77. - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 8
# Endereço: Av. Art. de Carvalho, 1515. - Porto Alegre, RS
# Latitude: None, Longitude: None
#
# 7
# Endereço: Av. Farroupilha, 4803 . 92020-475 - Canoas, RS
# Latitude: -29.911571, Longitude: -51.1635307
#
# 6
# Endereço: R Siqueira Campos 866 . 90010000 - Marechal Cândido Rondon, RS
# Latitude: None, Longitude: None
#
# 5
# Endereço: Av. Pres. Getúlio Vargas, 1509. 94810-000 - Alvorada, RS
# Latitude: None, Longitude: None
#
# 4
# Endereço: Av. Farroupilha, 4803 . 92020-475 - Canoas, RS
# Latitude: -29.911571, Longitude: -51.1635307
#
# 3
# Endereço: Av. Farroupilha 4803 Marechal Rondon. 92020-475 - Canoas, RS
# Latitude: -29.911571, Longitude: -51.1635307
#
# 2
# Endereço: Rua Liberdade, 1381. 92020-240 - Canoas, RS
# Latitude: -29.9046992, Longitude: -51.1695794
#
# 1
# Endereço: Rua Soledade, 133. 93295-150 - Esteio, RS
# Latitude: None, Longitude: None

# %%
# Exclui registros que vieram sem coordenadas
tabela_supermercados_com_info = tabela_supermercados[tabela_supermercados.latitude.isna() == False]

# %% [markdown]
# ## Verificando se uma coordenada está dentro da região do Multipolígono

# %%
# Função para processar as coordenadas do KML e criar polígonos
def process_coordinates(coordinate_string):
    coords = coordinate_string.replace('\n', '').split(' ')
    coords = [tuple(map(float, coord.split(',')[:2])) for coord in coords if coord]
    return Polygon(coords)

# %%
# Caminho para o arquivo KML
kml_path = 'regioes_afetadas_rs.kml'

# Abrir e ler o arquivo KML
with open(kml_path, 'r') as file:
    root = parser.parse(file).getroot()

# Lista para armazenar todos os polígonos, já que o arquivo no traz um multipolígono (um conjunto de polígonos)
polygons = []

# Iterar sobre todos os Placemarks
namespace = "{http://www.opengis.net/kml/2.2}"

for placemark in root.Document.Folder.findall('.//'+namespace+'Placemark'):
    for polygon in placemark.findall('.//'+namespace+'Polygon'):
        for outer_boundary in polygon.findall('.//'+namespace+'outerBoundaryIs'):
            for linear_ring in outer_boundary.findall('.//'+namespace+'LinearRing'):
                coord_text = linear_ring.coordinates.text
                poly = process_coordinates(coord_text)
                polygons.append(poly)

# %%
# Validando se as coordenadas de uma lista se encontram dentro da área de um multipolígono

i = 0
for index, row in tabela_supermercados_com_info.iterrows():
    i += 1
    print(i)
    
    latitude = float(row["latitude"])
    longitude = float(row["longitude"])
    point = Point(longitude, latitude)

    # Verificar se o ponto está em algum polígono
    is_inside = any(poly.contains(point) for poly in polygons)
    
    # Encontra a distância do polígono mais próximo da área
    min_distance = 1000000
    for poly in polygons:
        distance = point.distance(poly)
        if distance < min_distance:
            min_distance = distance         

    # Classifica os pontos conferindo se está dentro, próximo ou fora da região do mapa
    if is_inside:
        print("A coordenada está dentro de pelo menos um polígono.")
        tabela_supermercados_com_info.at[index, "afetado"] = "Região Afetada"
    elif min_distance <= 0.005:  
        print("O ponto está a menos de 500 metros do MultiPolígono.")
        tabela_supermercados_com_info.at[index, "afetado"] = "Região Próxima"
    else:
        print("O ponto não está dentro nem próximo ao MultiPolígono.")
        tabela_supermercados_com_info.at[index, "afetado"] = "Região Segura"
# Out:
# 1
# O ponto está a menos de 500 metros do MultiPolígono.
# 2
# A coordenada está dentro de pelo menos um polígono.
# 3
# A coordenada está dentro de pelo menos um polígono.
# 4
# O ponto está a menos de 500 metros do MultiPolígono.
# 5
# O ponto está a menos de 500 metros do MultiPolígono.
# 6
# A coordenada está dentro de pelo menos um polígono.
# 7
# A coordenada está dentro de pelo menos um polígono.
# 8
# O ponto não está dentro nem próximo ao MultiPolígono.
# 9
# O ponto está a menos de 500 metros do MultiPolígono.
# 10
# O ponto não está dentro nem próximo ao MultiPolígono.
# 11
# O ponto não está dentro nem próximo ao MultiPolígono.
# 12
# A coordenada está dentro de pelo menos um polígono.
# 13
# A coordenada está dentro de pelo menos um polígono.
# 14
# A coordenada está dentro de pelo menos um polígono.
# 15
# O ponto não está dentro nem próximo ao MultiPolígono.
# 16
# O ponto está a menos de 500 metros do MultiPolígono.
# 17
# O ponto não está dentro nem próximo ao MultiPolígono.
# 18
# O ponto não está dentro nem próximo ao MultiPolígono.
# 19
# A coordenada está dentro de pelo menos um polígono.
# 20
# A coordenada está dentro de pelo menos um polígono.
# 21
# A coordenada está dentro de pelo menos um polígono.
# 22
# O ponto não está dentro nem próximo ao MultiPolígono.
# 23
# O ponto não está dentro nem próximo ao MultiPolígono.
# 24
# O ponto não está dentro nem próximo ao MultiPolígono.
# 25
# O ponto não está dentro nem próximo ao MultiPolígono.
# 26
# A coordenada está dentro de pelo menos um polígono.
# 27
# O ponto está a menos de 500 metros do MultiPolígono.
# 28
# A coordenada está dentro de pelo menos um polígono.
# 29
# A coordenada está dentro de pelo menos um polígono.
# 30
# O ponto não está dentro nem próximo ao MultiPolígono.
# 31
# O ponto não está dentro nem próximo ao MultiPolígono.
# 32
# A coordenada está dentro de pelo menos um polígono.
# 33
# O ponto não está dentro nem próximo ao MultiPolígono.
# 34
# A coordenada está dentro de pelo menos um polígono.
# 35
# O ponto não está dentro nem próximo ao MultiPolígono.
# 36
# O ponto está a menos de 500 metros do MultiPolígono.
# 37
# O ponto não está dentro nem próximo ao MultiPolígono.
# 38
# O ponto está a menos de 500 metros do MultiPolígono.
# 39
# O ponto não está dentro nem próximo ao MultiPolígono.
# 40
# O ponto não está dentro nem próximo ao MultiPolígono.
# 41
# O ponto está a menos de 500 metros do MultiPolígono.
# 42
# O ponto está a menos de 500 metros do MultiPolígono.
# 43
# O ponto está a menos de 500 metros do MultiPolígono.
# 44
# A coordenada está dentro de pelo menos um polígono.
# 45
# O ponto não está dentro nem próximo ao MultiPolígono.
# 46
# A coordenada está dentro de pelo menos um polígono.
# 47
# O ponto não está dentro nem próximo ao MultiPolígono.
# 48
# O ponto está a menos de 500 metros do MultiPolígono.
# 49
# O ponto não está dentro nem próximo ao MultiPolígono.
# 50
# O ponto está a menos de 500 metros do MultiPolígono.
# 51
# O ponto está a menos de 500 metros do MultiPolígono.
# 52
# A coordenada está dentro de pelo menos um polígono.
# 53
# O ponto não está dentro nem próximo ao MultiPolígono.
# 54
# O ponto não está dentro nem próximo ao MultiPolígono.
# 55
# O ponto está a menos de 500 metros do MultiPolígono.
# 56
# O ponto não está dentro nem próximo ao MultiPolígono.
# 57
# O ponto não está dentro nem próximo ao MultiPolígono.
# 58
# A coordenada está dentro de pelo menos um polígono.
# 59
# O ponto não está dentro nem próximo ao MultiPolígono.
# 60
# O ponto está a menos de 500 metros do MultiPolígono.
# 61
# O ponto está a menos de 500 metros do MultiPolígono.
# 62
# O ponto não está dentro nem próximo ao MultiPolígono.
# 63
# A coordenada está dentro de pelo menos um polígono.
# 64
# O ponto está a menos de 500 metros do MultiPolígono.
# 65
# O ponto não está dentro nem próximo ao MultiPolígono.
# 66
# O ponto não está dentro nem próximo ao MultiPolígono.
# 67
# O ponto não está dentro nem próximo ao MultiPolígono.
# 68
# A coordenada está dentro de pelo menos um polígono.
# 69
# O ponto não está dentro nem próximo ao MultiPolígono.
# 70
# O ponto não está dentro nem próximo ao MultiPolígono.
# 71
# O ponto não está dentro nem próximo ao MultiPolígono.
# 72
# O ponto não está dentro nem próximo ao MultiPolígono.

# %%
tabela_supermercados_com_info.head()
# Out:
#                                      lista_enderecos   latitude  longitude  \
# 0  Avenida Plínio Brasil Milano 2343. - Porto Ale... -30.013230 -51.170902
# 1         Av. A. J. Renner, 1603. - Porto Alegre, RS -29.982955 -51.192105
# 2  Avenida Diario de Noticias, 500. 90810-080 - P... -30.083234 -51.244600
# 5  Rua Fernando Machado, 860 – Centro. 90010-320 ... -30.034537 -51.229020
# 6  Rua Marechal Floriano Peixoto, 333 – Centro. 9... -30.031859 -51.227178
#
#           afetado
# 0  Região Próxima
# 1  Região Afetada
# 2  Região Afetada
# 5  Região Próxima
# 6  Região Próxima

# %%
# Salva o arquivo em formato .xlsx
tabela_supermercados_com_info.to_excel("supermercados_poa.xlsx", index = False)
